# %%
import numpy as np
import pandas as pd

import scipy.stats as stats
import statsmodels.api as sm

import seaborn as sns
import matplotlib.pyplot as plt
#
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('dataset/car_price.csv')

df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
sns.displot(df['price'], kde=True)
plt.title('Car Price Distribution Data')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='Blues')
plt.title('Correlation Heatmap of Numerical Variables')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Numerical Variables')

# %%
sns.jointplot(data=df, x='enginesize', y='price', kind='reg').fig.suptitle("Scatter Plot & Histogram of Engine Size and Price")
plt.tight_layout()
plt.show()

# %%
df = df.sample(frac=1).reset_index(drop=True)

df.head()
# Out:
#    car_ID  symboling               CarName fueltype aspiration doornumber  \
# 0       6          2              audi fox      gas        std        two
# 1      81          3  mitsubishi mirage g4      gas      turbo        two
# 2     157          0        toyota mark ii      gas        std       four
# 3     199         -2           volvo 264gl      gas      turbo       four
# 4      15          1                bmw z4      gas        std       four
#
#      carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0      sedan        fwd          front       99.8  ...         136
# 1  hatchback        fwd          front       96.3  ...         110
# 2      sedan        fwd          front       95.7  ...          98
# 3      sedan        rwd          front      104.3  ...         130
# 4      sedan        rwd          front      103.5  ...         164
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
x = df['enginesize']

y = df['price']

# %%
# add constant (represent of intercept) to x variable (where y = a + bx)

x = sm.add_constant(x)
x.head()
# Out:
#    const  enginesize
# 0    1.0         136
# 1    1.0         110
# 2    1.0          98
# 3    1.0         130
# 4    1.0         164

# %%
train_size = int(0.75 * len(x))

x_train = x[:train_size]
y_train = y[:train_size]

x_test = x[train_size:]
y_test = y[train_size:]

# %%
x_train.shape, x_test.shape
# Out:
# ((153, 2), (52, 2))

# %%
model = sm.OLS(y_train, x_train).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     536.2
# Date:                Wed, 01 Mar 2023   Prob (F-statistic):           1.50e-51
# Time:                        13:01:28   Log-Likelihood:                -1481.1
# No. Observations:                 153   AIC:                             2966.
# Df Residuals:                     151   BIC:                             2972.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -8498.1636   1000.578     -8.493      0.000   -1.05e+04   -6521.224
# ...

# %% [markdown]
# * Let's start off by looking at the square of the model. It's .63, or 63%, which is a fairly good R‑square, considering that we used just 1 feature to predict the price. This R‑square implies that 63% of the variance in the underlying data was captured by this linear model.
# * This F‑statistic and the corresponding P‑value applies to the regression analysis as a whole, and it serves to indicate whether the regression analysis was valid. A P‑value less than the significance threshold of 5% indicates that this is indeed a valid analysis. The null hypothesis for this test is that all of our regression coefficients are equal to 0. That's clearly not the case, which is why we can reject the null hypothesis and accept the alternative hypothesis that our regression coefficients are not equal to 0
# * For every coefficient in our regression analysis, we generate a P‑statistic and a corresponding P‑value. This P‑statistic can be thought of as a measure of the precision with which the regression coefficient is measured, and it's a measure of the validity of this coefficient. A value of 0.001 indicates that our regression coefficient for the intercept, that's valid, and the same thing is true for the coefficient that corresponds to the horsepower variable. The P‑value here is 0, that is under our significance threshold, which means that this coefficient is also valid. The relationship between horsepower and the price is a statistically significant relationship, and that's what this T‑statistic and P‑value tells us.

# %%
fig = plt.figure(figsize=(12,8))

fig = sm.graphics.plot_regress_exog(model, 'enginesize', fig=fig)

plt.show()

# %% [markdown]
# The plot_regress_exog function in stats models allows you to view the regression results against a single regressor. The regressor here is horsepower. Now this generates four different plots
# * The first one here plots the fitted values of our regression line, represented in red against the actual values for horsepower and price. The vertical lines here are the prediction confidence intervals for each of the fitted values
# * This plot here, the plot of the residuals of the regression versus the predictor variable, that is, horsepower, allows us to see whether residuals have non‑linear patterns. Here, the fact that the residuals are evenly spread out around the 0 line indicates that our regression does not have any non‑linear patterns. This is a good indication that we don't have non‑linear relationships that we need to model here. Linear regression is a good choice
# * A Partial regression plot attempts to show the effect of adding another variable to a model that already has one or more independent variables. Now, this is a model with just one variable, so the Partial regression plot is simply a scatter plot of price versus horsepower with a fitted regression line on this scatter plot
# * And finally, the CCPR, or the component, component‑plus‑residual plot provides a way to judge the effect of one regressor on the response variable, that is price here, by taking into account the effects of the other independent variables. There are no other independent variables here in this regression. Once again, we have a scatter plot with a linear model fit on our data.

# %%
sm.graphics.influence_plot(model)

# %% [markdown]
# You can also use the influence_plot to better understand your regression model. The influence_plot allows you to see which records in your data have had an outsized influence on the regression analysis. Those data points which have large circles, those are influential data points. The record with ID 35, 129, those have had an outsized impact on our regression.

# %%
y_pred = model.predict(x_test)

y_pred.head()
# Out:
# 153     3589.534891
# 154    15849.914761
# 155     7388.525836
# 156    10496.791156
# 157     7388.525836
# dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test['enginesize'], y_test)
plt.plot(x_test['enginesize'], y_pred, color='g')

plt.xlabel('Engine Size')
plt.ylabel('Price')

plt.show()

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.690379163402254
